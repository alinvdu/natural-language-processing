# %%
import os
import string

def read_poems(file_path, label):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        
    remove_punct = str.maketrans('', '', string.punctuation)
        
    lines = [line.translate(remove_punct).strip().lower() for line in lines if line.strip()]
    return lines

data = read_poems("./../data/robert_frost.txt", 1)

# %%
from collections import defaultdict

def create_mapping(data):
    word_to_index = defaultdict(lambda: len(word_to_index))
    word_to_index["<UNK>"] = 0 # special token for unknown words
    
    for line in data:
        words = line.split()
        [word_to_index[word] for word in words]
        
    return dict(word_to_index)

word_to_index = create_mapping(data)

# %%
index_to_word = {index: word for word, index in word_to_index.items()}

# %%
word_to_index
# Out:
# {'<UNK>': 0,
#  'two': 1,
#  'roads': 2,
#  'diverged': 3,
#  'in': 4,
#  'a': 5,
#  'yellow': 6,
#  'wood': 7,
#  'and': 8,
#  'sorry': 9,
#  'i': 10,
#  'could': 11,
#  'not': 12,
#  'travel': 13,
#  'both': 14,
#  'be': 15,
#  'one': 16,
#  'traveler': 17,
#  'long': 18,
#  'stood': 19,
#  'looked': 20,
#  'down': 21,
#  'as': 22,
#  'far': 23,
#  'to': 24,
#  'where': 25,
#  'it': 26,
#  'bent': 27,
#  'the': 28,
#  'undergrowth': 29,
#  'then': 30,
#  'took': 31,
#  'other': 32,
#  'just': 33,
#  'fair': 34,
#  'having': 35,
#  'perhaps': 36,
#  'better': 37,
#  'claim': 38,
#  'because': 39,
#  'was': 40,
#  'grassy': 41,
#  'wanted': 42,
#  'wear': 43,
#  'though': 44,
#  'for': 45,
#  'that': 46,
#  'passing': 47,
#  'there': 48,
#  'had': 49,
#  'worn': 50,
#  'them': 51,
#  'really': 52,
#  'about': 53,
#  'same': 54,
#  'morning': 55,
#  'equally': 56,
#  'lay': 57,
#  'leaves': 58,
#  'no': 59,
#  'step': 60,
#  'trodden': 61,
#  'black': 62,
#  'oh': 63,
#  'kept': 64,
#  'first': 65,
#  'another': 66,
#  'day': 67,
#  'yet': 68,
#  'knowing': 69,
#  'how': 70,
#  'way': 71,
#  'leads': 72,
#  'on': 73,
#  'doubted': 74,
#  'if': 75,
#  'should': 76,
#  'ever': 77,
#  'come': 78,
#  'back': 79,
#  'shall': 80,
#  'telling': 81,
#  'this': 82,
#  'with': 83,
#  'sigh': 84,
#  'somewhere': 85,
#  'ages': 86,
#  'hence': 87,
#  'less': 88,
#  'traveled': 89,
#  'by': 90,
#  'has': 91,
#  'made': 92,
#  'all': 93,
#  'difference': 94,
#  'whose': 95,
#  'woods': 96,
#  'these': 97,
#  'are': 98,
#  'think': 99,
#  'know': 100,
#  'his': 101,
#  'house': 102,
#  'is': 103,
#  'village': 104,
#  'he': 105,
#  'will': 106,
#  'see': 107,
#  'me': 108,
#  'stopping': 109,
#  'here': 110,
#  'watch': 111,
#  'fill': 112,
#  'up': 113,
#  'snow': 114,
#  'my': 115,
#  'little': 116,
#  'horse': 117,
#  'must': 118,
#  'queer': 119,
#  'stop': 120,
#  'without': 121,
#  'farmhouse': 122,
#  'near': 123,
#  'between': 124,
#  'frozen': 125,
#  'lake': 126,
#  'darkest': 127,
#  'evening': 128,
#  'of': 129,
#  'year': 130,
#  'gives': 131,
#  'harness': 132,
#  'bells': 133,
#  'shake': 134,
#  'ask': 135,
#  'some': 136,
#  'mistake': 137,
#  'only': 138,
#  'sounds': 139,
#  'sweep': 140,
#  'easy': 141,
#  'wind': 142,
#  'downy': 143,
#  'flake': 144,
#  'lovely': 145,
#  'dark': 146,
#  'deep': 147,
#  'but': 148,
#  'have': 149,
#  'promises': 150,
#  'keep': 151,
#  'miles': 152,
#  'go': 153,
#  'before': 154,
#  'sleep': 155,
#  'say': 156,
#  'world': 157,
#  'end': 158,
#  'fire': 159,
#  'ice': 160,
#  'from': 161,
#  'what': 162,
#  'ive': 163,
#  'tasted': 164,
#  'desire': 165,
#  'hold': 166,
#  'those': 167,
#  'who': 168,
#  'favor': 169,
#  'perish': 170,
#  'twice': 171,
#  'enough': 172,
#  'hate': 173,
#  'destruction': 174,
#  'also': 175,
#  'great': 176,
#  'would': 177,
#  'suffice': 178,
#  'natures': 179,
#  'green': 180,
#  'gold': 181,
#  'her': 182,
#  'hardest': 183,
#  'hue': 184,
#  'early': 185,
#  'leafs': 186,
#  'flower': 187,
#  'so': 188,
#  'an': 189,
#  'hour': 190,
#  'leaf': 191,
#  'subsides': 192,
#  'eden': 193,
#  'sank': 194,
#  'grief': 195,
#  'dawn': 196,
#  'goes': 197,
#  'nothing': 198,
#  'can': 199,
#  'stay': 200,
#  'been': 201,
#  'acquainted': 202,
#  'night': 203,
#  'walked': 204,
#  'out': 205,
#  'rain': 206,
#  'outwalked': 207,
#  'furthest': 208,
#  'city': 209,
#  'light': 210,
#  'saddest': 211,
#  'lane': 212,
#  'passed': 213,
#  'watchman': 214,
#  'beat': 215,
#  'dropped': 216,
#  'eyes': 217,
#  'unwilling': 218,
#  'explain': 219,
#  'still': 220,
#  'stopped': 221,
#  'sound': 222,
#  'feet': 223,
#  'when': 224,
#  'away': 225,
#  'interrupted': 226,
#  'cry': 227,
#  'came': 228,
#  'over': 229,
#  'houses': 230,
#  'street': 231,
#  'call': 232,
#  'or': 233,
#  'goodbye': 234,
#  'further': 235,
#  'at': 236,
#  'unearthly': 237,
#  'height': 238,
#  'luminary': 239,
#  'clock': 240,
#  'against': 241,
#  'sky': 242,
#  'proclaimed': 243,
#  'time': 244,
#  'neither': 245,
#  'wrong': 246,
#  'nor': 247,
#  'right': 248,
#  'through': 249,
#  'mowing': 250,
#  'field': 251,
#  'headless': 252,
#  'aftermath': 253,
#  'smoothlaid': 254,
#  'like': 255,
#  'thatch': 256,
#  'heavy': 257,
#  'dew': 258,
#  'half': 259,
#  'closes': 260,
#  'garden': 261,
#  'path': 262,
#  'ground': 263,
#  'whir': 264,
#  'sober': 265,
#  'birds': 266,
#  'tangle': 267,
#  'withered': 268,
#  'weeds': 269,
#  'sadder': 270,
#  'than': 271,
#  'any': 272,
#  'words': 273,
#  'tree': 274,
#  'beside': 275,
#  'wall': 276,
#  'stands': 277,
#  'bare': 278,
#  'lingered': 279,
#  'brown': 280,
#  'disturbed': 281,
#  'doubt': 282,
#  'thought': 283,
#  'comes': 284,
#  'softly': 285,
#  'rattling': 286,
#  'going': 287,
#  'forth': 288,
#  'picking': 289,
#  'faded': 290,
#  'blue': 291,
#  'last': 292,
#  'remaining': 293,
#  'aster': 294,
#  'carry': 295,
#  'again': 296,
#  'you': 297,
#  'voice': 298,
#  'said': 299,
#  'look': 300,
#  'stars': 301,
#  'tell': 302,
#  'truly': 303,
#  'men': 304,
#  'earth': 305,
#  'soulandbody': 306,
#  'scars': 307,
#  'were': 308,
#  'too': 309,
#  'much': 310,
#  'pay': 311,
#  'birth': 312,
#  'country': 313,
#  'now': 314,
#  'hillside': 315,
#  'sun': 316,
#  'lets': 317,
#  'ten': 318,
#  'million': 319,
#  'silver': 320,
#  'lizards': 321,
#  'often': 322,
#  'seen': 323,
#  'done': 324,
#  'cant': 325,
#  'pretend': 326,
#  'its': 327,
#  'looks': 328,
#  'magic': 329,
#  'lifted': 330,
#  'rug': 331,
#  'bred': 332,
#  'floor': 333,
#  'breaking': 334,
#  'run': 335,
#  'wet': 336,
#  'stampede': 337,
#  'caught': 338,
#  'lizard': 339,
#  'tail': 340,
#  'put': 341,
#  'foot': 342,
#  'avail': 343,
#  'threw': 344,
#  'myself': 345,
#  'wetelbowed': 346,
#  'wetkneed': 347,
#  'front': 348,
#  'twenty': 349,
#  'others': 350,
#  'wriggling': 351,
#  'speed': 352,
#  'confusion': 353,
#  'aglitter': 354,
#  'joined': 355,
#  'excited': 356,
#  'fun': 357,
#  'doubling': 358,
#  'redoubling': 359,
#  'song': 360,
#  'twitter': 361,
#  'id': 362,
#  'holding': 363,
#  'none': 364,
#  'takes': 365,
#  'moon': 366,
#  'suns': 367,
#  'wizard': 368,
#  'sos': 369,
#  'witch': 370,
#  'high': 371,
#  'west': 372,
#  'she': 373,
#  'makes': 374,
#  'gentle': 375,
#  'cast': 376,
#  'suddenly': 377,
#  'jerk': 378,
#  'twitch': 379,
#  'speel': 380,
#  'every': 381,
#  'single': 382,
#  'fancied': 383,
#  'six': 384,
#  'oclock': 385,
#  'swarm': 386,
#  'ran': 387,
#  'scuttled': 388,
#  'fast': 389,
#  'waiting': 390,
#  'chill': 391,
#  'effect': 392,
#  'nine': 393,
#  'turned': 394,
#  'rock': 395,
#  'lifelike': 396,
#  'posture': 397,
#  'transfixed': 398,
#  'mountain': 399,
#  'slopes': 400,
#  'almost': 401,
#  'erect': 402,
#  'across': 403,
#  'each': 404,
#  'side': 405,
#  'they': 406,
#  'spell': 407,
#  'wrought': 408,
#  'trees': 409,
#  'breath': 410,
#  'storm': 411,
#  'make': 412,
#  'stir': 413,
#  'ray': 414,
#  'attempting': 415,
#  'such': 416,
#  'stray': 417,
#  'once': 418,
#  'kind': 419,
#  'called': 420,
#  'weather': 421,
#  'breeder': 422,
#  'heat': 423,
#  'slowly': 424,
#  'hazes': 425,
#  'own': 426,
#  'power': 427,
#  'seems': 428,
#  'undone': 429,
#  'boring': 430,
#  'climbing': 431,
#  'swamp': 432,
#  'cedar': 433,
#  'choked': 434,
#  'oil': 435,
#  'scurf': 436,
#  'plants': 437,
#  'weary': 438,
#  'overheated': 439,
#  'left': 440,
#  'road': 441,
#  'knew': 442,
#  'paused': 443,
#  'rested': 444,
#  'sort': 445,
#  'hook': 446,
#  'coat': 447,
#  'good': 448,
#  'seated': 449,
#  'since': 450,
#  'toward': 451,
#  'heaven': 452,
#  'resurrected': 453,
#  'raised': 454,
#  'again—': 455,
#  'barkless': 456,
#  'spectre': 457,
#  'halted': 458,
#  'fear': 459,
#  'treading': 460,
#  'upon': 461,
#  'saw': 462,
#  'strange': 463,
#  'position': 464,
#  'hands—': 465,
#  'shoulders': 466,
#  'dragging': 467,
#  'strands': 468,
#  'wire': 469,
#  'something': 470,
#  'arent': 471,
#  'nowadays': 472,
#  'whats': 473,
#  'news': 474,
#  'carry—if': 475,
#  'youre': 476,
#  'off': 477,
#  'for—montreal': 478,
#  'im': 479,
#  'anywhere': 480,
#  'sometimes': 481,
#  'wander': 482,
#  'beaten': 483,
#  'ways': 484,
#  'looking': 485,
#  'orchid': 486,
#  'calypso': 487,
#  'lived': 488,
#  'lofty': 489,
#  'farm': 490,
#  'everyone': 491,
#  'lantern': 492,
#  'did': 493,
#  'chores': 494,
#  'winter': 495,
#  'after': 496,
#  'halfpast': 497,
#  'three': 498,
#  'many': 499,
#  'him': 500,
#  'wild': 501,
#  'descent': 502,
#  'cross': 503,
#  'lots': 504,
#  'walls': 505,
#  'everything': 506,
#  'describing': 507,
#  'rings': 508,
#  'barn': 509,
#  'gale': 510,
#  'got': 511,
#  'blew': 512,
#  'icy': 513,
#  'crust': 514,
#  'cased': 515,
#  'gone': 516,
#  'buried': 517,
#  'few': 518,
#  'unless': 519,
#  'stove': 520,
#  'hole': 521,
#  'heel': 522,
#  'repeatedly': 523,
#  'strove': 524,
#  'stamped': 525,
#  'things': 526,
#  'himself': 527,
#  'seemed': 528,
#  'yield': 529,
#  'gained': 530,
#  'foothold': 531,
#  'pursued': 532,
#  'journey': 533,
#  'arms': 534,
#  'outspread': 535,
#  'wings': 536,
#  'revolving': 537,
#  'scene': 538,
#  'longer': 539,
#  'axis': 540,
#  'small': 541,
#  'dignity': 542,
#  'mien': 543,
#  'faster': 544,
#  'slower': 545,
#  'chanced': 546,
#  'sitting': 547,
#  'standing': 548,
#  'chose': 549,
#  'according': 550,
#  'feared': 551,
#  'risk': 552,
#  'neck': 553,
#  'spare': 554,
#  'clothes': 555,
#  'never': 556,
#  'let': 557,
#  'drop': 558,
#  'exclaimed': 559,
#  'afar': 560,
#  'figures': 561,
#  'described': 562,
#  'wonder': 563,
#  'signals': 564,
#  'hes': 565,
#  'celebrating': 566,
#  'sold': 567,
#  'master': 568,
#  'grange': 569,
#  'reeled': 570,
#  'lurched': 571,
#  'bobbed': 572,
#  'checked': 573,
#  'fell': 574,
#  'rattle': 575,
#  'saved': 576,
#  'halfway': 577,
#  'fought': 578,
#  'battle': 579,
#  'incredulous': 580,
#  'bad': 581,
#  'luck': 582,
#  'becoming': 583,
#  'reconciled': 584,
#  'gave': 585,
#  'coasting': 586,
#  'child': 587,
#  'well—i—be—': 588,
#  'river': 589,
#  'slippery': 590,
#  'slope': 591,
#  'abode': 592,
#  'authority': 593,
#  'motorcars': 594,
#  'asked': 595,
#  'our': 596,
#  'stock': 597,
#  'petered': 598,
#  'sincere': 599,
#  'reply': 600,
#  'yankees': 601,
#  'always': 602,
#  'dont': 603,
#  'hope': 604,
#  'getting': 605,
#  'home': 606,
#  'couldnt': 607,
#  'climb': 608,
#  'even': 609,
#  'until': 610,
#  'january': 611,
#  'thaw': 612,
#  'take': 613,
#  'polish': 614,
#  'bowed': 615,
#  'grace': 616,
#  'natural': 617,
#  'law': 618,
#  'went': 619,
#  'round': 620,
#  'manner': 621,
#  'concerned': 622,
#  'whom': 623,
#  'particular': 624,
#  'course': 625,
#  'steered': 626,
#  'straight': 627,
#  'which': 628,
#  'headed': 629,
#  'for—': 630,
#  'more': 631,
#  'became': 632,
#  'man—': 633,
#  'politician': 634,
#  'odd': 635,
#  'seasons': 636,
#  'cold': 637,
#  'while': 638,
#  'invested': 639,
#  'reasons': 640,
#  'snapped': 641,
#  'times': 642,
#  'shook': 643,
#  'saying': 644,
#  'iles': 645,
#  'bout': 646,
#  'matter': 647,
#  'several': 648,
#  'theyve': 649,
#  'settled': 650,
#  'wont': 651,
#  'prove': 652,
#  'flattered': 653,
#  'towns': 654,
#  'fighting': 655,
#  'present': 656,
#  'dispose': 657,
#  'either': 658,
#  'trouble': 659,
#  'double': 660,
#  'troubles': 661,
#  'witchs': 662,
#  'motto': 663,
#  'anyway': 664,
#  'ill': 665,
#  'theirs': 666,
#  'theyll': 667,
#  'find': 668,
#  'whole': 669,
#  'thing': 670,
#  'do': 671,
#  'facts': 672,
#  'want': 673,
#  'set': 674,
#  'lot': 675,
#  'record': 676,
#  'arthur': 677,
#  'amys': 678,
#  'hog': 679,
#  'reeve': 680,
#  'march': 681,
#  'meeting': 682,
#  'warren': 683,
#  'told': 684,
#  'twelvemonth': 685,
#  'amy': 686,
#  'married': 687,
#  'reason': 688,
#  'fifteen': 689,
#  'voted': 690,
#  'wasnt': 691,
#  'town': 692,
#  'wentworth': 693,
#  'twas': 694,
#  'warrant': 695,
#  'tote': 696,
#  'clearing': 697,
#  'we': 698,
#  'whod': 699,
#  'remember': 700,
#  'heman': 701,
#  'lapish': 702,
#  'their': 703,
#  'father': 704,
#  'mine': 705,
#  'dragged': 706,
#  'courts': 707,
#  'guess': 708,
#  'theyd': 709,
#  'drag': 710,
#  'warrens': 711,
#  'live': 712,
#  'happen': 713,
#  'prefer': 714,
#  'alls': 715,
#  'rights': 716,
#  'temptation': 717,
#  'hurt': 718,
#  'someone': 719,
#  'doing': 720,
#  'folks': 721,
#  'thatd': 722,
#  'noted': 723,
#  'most': 724,
#  'expense': 725,
#  'ought': 726,
#  'milk': 727,
#  'bat': 728,
#  'days': 729,
#  'itd': 730,
#  'stronger': 731,
#  'consent': 732,
#  'give': 733,
#  'sign': 734,
#  'surer': 735,
#  'spose': 736,
#  'mallice': 737,
#  'huse': 738,
#  'old': 739,
#  'age': 740,
#  'rode': 741,
#  'skin': 742,
#  'bones': 743,
#  'hitched': 744,
#  'unblanketed': 745,
#  'hall': 746,
#  'grafton': 747,
#  'county': 748,
#  'cried': 749,
#  'shame': 750,
#  'blanket': 751,
#  'poor': 752,
#  'man': 753,
#  'hadnt': 754,
#  'gnaw': 755,
#  'posts': 756,
#  'leave': 757,
#  'trade': 758,
#  'mark': 759,
#  'recognize': 760,
#  'post': 761,
#  'hear': 762,
#  'scarified': 763,
#  'gnawing': 764,
#  'till': 765,
#  'whined': 766,
#  'smarty': 767,
#  'hed': 768,
#  'bet': 769,
#  'cribber': 770,
#  'gnawed': 771,
#  'crib': 772,
#  'slept': 773,
#  'sures': 774,
#  'born': 775,
#  'found': 776,
#  'four': 777,
#  'bed': 778,
#  'splinters': 779,
#  'hitching': 780,
#  'besides': 781,
#  'gnaws': 782,
#  'stable': 783,
#  'aint': 784,
#  'proof': 785,
#  'fences': 786,
#  'everybody': 787,
#  'strapping': 788,
#  'girl': 789,
#  'spoiled': 790,
#  'started': 791,
#  'courting': 792,
#  'mistrusted': 793,
#  'proud': 794,
#  'interfered': 795,
#  'business': 796,
#  'happened': 797,
#  'turn': 798,
#  'undo': 799,
#  'kiting': 800,
#  'nights': 801,
#  'shes': 802,
#  'thinks': 803,
#  'might': 804,
#  'well': 805,
#  'herself': 806,
#  'liked': 807,
#  'best': 808,
#  'plagued': 809,
#  'death': 810,
#  'anyone': 811,
#  'coming': 812,
#  'ridgepole': 813,
#  'stride': 814,
#  'broomstick': 815,
#  'guessed': 816,
#  'showed': 817,
#  'signs': 818,
#  'smells': 819,
#  'wash': 820,
#  'ploughed': 821,
#  'seven': 822,
#  'years': 823,
#  'mean': 824,
#  'skulls': 825,
#  'rogers': 826,
#  'rangers': 827,
#  'moosilauke': 828,
#  'woman': 829,
#  'bewitched': 830,
#  'grow': 831,
#  'short': 832,
#  'mosses': 833,
#  'tall': 834,
#  'gather': 835,
#  'berries': 836,
#  'rocks': 837,
#  'waterfall': 838,
#  'sees': 839,
#  'aknown': 840,
#  'young': 841,
#  'full': 842,
#  'doesnt': 843,
#  'seem': 844,
#  'courage': 845,
#  'free': 846,
#  'kick': 847,
#  'faces': 848,
#  'davis': 849,
#  'owned': 850,
#  'solid': 851,
#  'mica': 852,
#  'dalton': 853,
#  'someday': 854,
#  'fortune': 855,
#  'thered': 856,
#  'boston': 857,
#  'people': 858,
#  'experts': 859,
#  'sheets': 860,
#  'big': 861,
#  'plateglass': 862,
#  'windows': 863,
#  'show': 864,
#  'place': 865,
#  'kinsman': 866,
#  'mormons': 867,
#  'settlement': 868,
#  'built': 869,
#  'stone': 870,
#  'baptismal': 871,
#  'font': 872,
#  'outdoors': 873,
#  'smith': 874,
#  'worse': 875,
#  'fight': 876,
#  'desert': 877,
#  'youd': 878,
#  'today': 879,
#  'huh': 880,
#  'bathtub': 881,
#  'talk': 882,
#  'shut': 883,
#  'fountain': 884,
#  'summer': 885,
#  'united': 886,
#  'strengths': 887,
#  'youve': 888,
#  'lost': 889,
#  'grown': 890,
#  'around': 891,
#  'may': 892,
#  'shifted': 893,
#  'eightyfive': 894,
#  'ago': 895,
#  'rightly': 896,
#  'sprung': 897,
#  'leak': 898,
#  'emptied': 899,
#  'forty': 900,
#  'deal': 901,
#  'masonry': 902,
#  'mormon': 903,
#  'swimming': 904,
#  'am': 905,
#  'everywhere': 906,
#  'guide': 907,
#  'thats': 908,
#  'why': 909,
#  'decently': 910,
#  'refuse': 911,
#  'ascending': 912,
#  'descend': 913,
#  'reascend': 914,
#  'seriously': 915,
#  'bearings': 916,
#  'spoke': 917,
#  'doubts': 918,
#  'open': 919,
#  'lookoff': 920,
#  'faced': 921,
#  'cliff': 922,
#  'bottle': 923,
#  'painted': 924,
#  'stained': 925,
#  'vegetation': 926,
#  'above': 927,
#  'likeness': 928,
#  'surprise': 929,
#  'thrilly': 930,
#  'tourist': 931,
#  'havent': 932,
#  'brought': 933,
#  'least': 934,
#  'famous': 935,
#  'accept': 936,
#  'substitute': 937,
#  'empty': 938,
#  'tells': 939,
#  'suspected': 940,
#  'treat': 941,
#  'your': 942,
#  'due': 943,
#  'respect': 944,
#  'spend': 945,
#  'vow': 946,
#  'converging': 947,
#  'slides': 948,
#  'avalanches': 949,
#  'marshall': 950,
#  'donkeys': 951,
#  'ears': 952,
#  'save': 953,
#  'suggest': 954,
#  'gods': 955,
#  'sake': 956,
#  'fond': 957,
#  'viewing': 958,
#  'nature': 959,
#  'books': 960,
#  'signify': 961,
#  'cars': 962,
#  'however': 963,
#  'fall': 964,
#  'abouncing': 965,
#  'hell': 966,
#  'knees': 967,
#  'hellforleather': 968,
#  'ready': 969,
#  'anything': 970,
#  'struck': 971,
#  'didnt': 972,
#  'welcomed': 973,
#  'chance': 974,
#  'lave': 975,
#  'shoes': 976,
#  'dust': 977,
#  'followed': 978,
#  'mile': 979,
#  'ended': 980,
#  'bring': 981,
#  'broadboard': 982,
#  'paneling': 983,
#  'deserted': 984,
#  'excuse': 985,
#  'window': 986,
#  'happens': 987,
#  'broken': 988,
#  'outside': 989,
#  'doors': 990,
#  'held': 991,
#  'us': 992,
#  'introduce': 993,
#  'used': 994,
#  'robinsons': 995,
#  'heard': 996,
#  'clara': 997,
#  'robinson': 998,
#  'poetess': 999,
#  ...}

# %%
def tokenize_and_convert(data, word_to_index):
    tokenized_data = []
    for line in data:
        words = line.split()
        if len(words) > 2:
            tokenized_line = [word_to_index[word] if word in word_to_index else word_to_index["<UNK>"] for word in words]
            tokenized_data.append(tokenized_line)
    return tokenized_data


data_tokenized = tokenize_and_convert(data, word_to_index)

# %%
print(data[0])
print(data_tokenized[0])
# Out:
# two roads diverged in a yellow wood
# [1, 2, 3, 4, 5, 6, 7]

# %%
transitions_counts = {}
initial_state_distrib = {}

for line in data_tokenized:
    # first register the initial distribution
    initial_state_distrib[line[0], line[1]] = initial_state_distrib.get((line[0], line[1]), 0) + 1
    
    for i in range(len(line) - 2):
        currentDict = transitions_counts.get((line[i], line[i+1]), {})
        currentDict[line[i+2]] = currentDict.get(line[i+2], 0) + 1
        transitions_counts[line[i], line[i+1]] = currentDict
        
print(transitions_counts)
# Out:
# {(1, 2): {3: 2}, (2, 3): {4: 2}, (3, 4): {5: 2}, (4, 5): {6: 1, 7: 1, 986: 1, 1026: 1, 1424: 1, 1042: 1, 1410: 1, 1714: 1, 244: 1, 692: 1, 1001: 1, 1924: 1, 1019: 2}, (5, 6): {7: 1}, (8, 9): {10: 2}, (9, 10): {11: 1, 77: 1}, (10, 11): {12: 2, 149: 2, 107: 3, 671: 1}, (11, 12): {13: 1, 156: 1}, (12, 13): {14: 1}, (8, 15): {16: 1, 669: 1}, (15, 16): {17: 1}, (16, 17): {18: 1}, (17, 18): {10: 1}, (18, 10): {19: 1, 57: 1}, (8, 20): {21: 1}, (20, 21): {16: 1, 28: 1}, (21, 16): {22: 1, 231: 1}, (16, 22): {23: 1}, (22, 23): {22: 2}, (23, 22): {10: 1, 698: 1}, (22, 10): {11: 1, 905: 1, 671: 1, 156: 1}, (24, 25): {26: 2}, (25, 26): {27: 1, 980: 1, 574: 1, 1224: 1, 228: 1, 103: 1}, (26, 27): {4: 1}, (27, 4): {28: 1}, (4, 28): {29: 1, 104: 1, 301: 1, 353: 1, 356: 1, 538: 1, 589: 1, 637: 2, 692: 1, 695: 1, 783: 1, 738: 1, 340: 1, 146: 2, 399: 1, 1096: 1, 203: 1, 1231: 1, 1225: 7, 1310: 1, 210: 1, 1243: 1, 1015: 2, 1446: 1, 206: 1, 316: 1, 938: 1, 919: 1, 1230: 1, 421: 1, 1833: 1, 1852: 1, 1869: 1, 1905: 1, 1994: 1, 423: 1, 2031: 1}, (30, 31): {28: 1}, (31, 28): {32: 1, 16: 1, 18: 1, 746: 1}, (28, 32): {22: 1}, (32, 22): {33: 1}, (22, 33): {22: 1}, (33, 22): {34: 1, 389: 2, 938: 1, 805: 1}, (8, 35): {36: 1}, (35, 36): {28: 1}, (36, 28): {37: 1}, (28, 37): {38: 1}, (39, 26): {40: 1}, (26, 40): {41: 1, 24: 1, 28: 2, 93: 1, 48: 1, 243: 1, 1653: 1, 1508: 1, 812: 1, 18: 1, 581: 1}, (40, 41): {8: 1}, (41, 8): {42: 1
059490085, (8, 344): 0.000708215297450425, (4, 348): 0.002124645892351275, (4, 28): 0.000708215297450425, (8, 266): 0.000708215297450425, (90, 358): 0.000708215297450425, (26, 365): 0.000708215297450425, (90, 93): 0.000708215297450425, (161, 28): 0.0028328611898017, (8, 377): 0.000708215297450425, (373, 91): 0.000708215297450425, (10, 383): 0.000708215297450425, (28, 386): 0.000708215297450425, (28, 366): 0.000708215297450425, (10, 20): 0.000708215297450425, (4, 381): 0.00141643059490085, (398, 73): 0.000708215297450425, (403, 404): 0.000708215297450425, (28, 407): 0.000708215297450425, (40, 408): 0.000708215297450425, (24, 412): 0.00424929178470255, (16, 339): 0.000708215297450425, (28, 283): 0.000708215297450425, (418, 73): 0.000708215297450425, (224, 28): 0.000708215297450425, (90, 327): 0.000708215297450425, (10, 40): 0.00424929178470255, (5, 432): 0.000708215297450425, (8, 436): 0.000708215297450425, (10, 443): 0.000708215297450425, (46, 49): 0.00141643059490085, (8, 450): 0.00141643059490085, (20, 113): 0.000708215297450425, (19, 229): 0.000708215297450425, (5, 456): 0.000708215297450425, (22, 75): 0.00141643059490085, (10, 462):  ...

# %%
import random

def generate_boundaries_and_pick_number(distr):
    boundaries = {}
    previous_boundaries = 0
    for keys, prob in distr.items():
        boundaries[keys] = previous_boundaries + prob
        previous_boundaries = boundaries[keys]
        
    # generate a random numbet between 0 and 1
    choosen = random.uniform(0, 1)
    answer = (0, 0)
    for keys, acc in boundaries.items():
        if choosen < acc:
            answer = keys
            break
    
    return answer

def pick_next(word_one, word_two, transition_probs, initial_state_distrib_probs):
    next_probs = 0
    while not next_probs:
        if transition_probs.get(word_one, word_two):
            next_word = transition_probs.get(word_one, word_two)
        else:
            (word_one, word_two) = generate_boundaries_for_tuple_and_pick_number(initial_state_distrib)
            
def detokenize(word_index, index_to_word):
    return index_to_word[word_index]

def generate_line(transition_probs, initial_state_distrib_probs, Nwords):
    # pick the initial start
    (word_one, previous_word) = generate_boundaries_and_pick_number(initial_state_distrib_probs)
    next_word = generate_boundaries_and_pick_number(transition_probs.get((word_one, previous_word)))
    sequence = [detokenize(word_one, index_to_word), detokenize(previous_word, index_to_word),
                detokenize(next_word, index_to_word)]

    while len(sequence) < Nwords:
        if transition_probs.get((previous_word, next_word)):
            next_word = generate_boundaries_and_pick_number(transition_probs.get((previous_word, next_word)))
            sequence.append(detokenize(next_word, index_to_word))
        else:
            (word_one, word_two) = generate_boundaries_and_pick_number(initial_state_distrib_probs)
            previous_word = word_one
            next_word = word_two
            sequence.append(detokenize(previous_word, index_to_word))
            sequence.append(detokenize(next_word, index_to_word))
            
    return sequence

nrOfLines = 5
poem = ''
for i in range(nrOfLines):
    lines = generate_line(transition_probs, initial_state_distrib_probs, 8)
    poem += " ".join(lines)
    poem += '\n'
    
print(poem)
# Out:
# he never said much by its own what are
# he never let them then we asked brown makes
# a featherhammer gives a thence they were i made
# and i dread the out in rain perhaps you
# on his feet against and if youre her
