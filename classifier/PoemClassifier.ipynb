# %%
import os
import string

def read_poems(file_path, label):
    with open(file_path, 'r') as file:
        lines = file.readlines()
        
    remove_punct = str.maketrans('', '', string.punctuation)
        
    lines = [line.translate(remove_punct).strip().lower() for line in lines if line.strip()]
    return [(line, label) for line in lines]

poe_lines = read_poems("./../data/edgar_allan_poe.txt", 0)
frost_lines = read_poems("./../data/robert_frost.txt", 1)

# %%
print(poe_lines[0])
print(frost_lines[1])
# Out:
# ('lo death hath reard himself a throne', 0)
# ('and sorry i could not travel both', 1)

# %%
data_poe, labels_poe = zip(*poe_lines)
data_frost, labels_frost = zip(*frost_lines)

data = data_poe + data_frost
labels = labels_poe + labels_frost

# %%
# Split
from sklearn.model_selection import train_test_split

train_text, test_text, Ytrain, Ytest = train_test_split(data, labels)

# %%
from collections import defaultdict

def create_mapping(data):
    word_to_index = defaultdict(lambda: len(word_to_index))
    word_to_index["<UNK>"] = 0 # special token for unknown words
    
    for line in data:
        words = line.split()
        [word_to_index[word] for word in words]
        
    return dict(word_to_index)

word_to_index = create_mapping(train_text)

# %%
word_to_index
# Out:
# {'<UNK>': 0,
#  'with': 1,
#  'hope': 2,
#  'and': 3,
#  'in': 4,
#  'beauty': 5,
#  'tonight': 6,
#  'i': 7,
#  'had': 8,
#  'such': 9,
#  'company': 10,
#  'outward': 11,
#  'bound': 12,
#  'front': 13,
#  'of': 14,
#  'one': 15,
#  'town': 16,
#  'hall': 17,
#  'id': 18,
#  'left': 19,
#  'him': 20,
#  'hitched': 21,
#  'im': 22,
#  'getting': 23,
#  'too': 24,
#  'old': 25,
#  'for': 26,
#  'my': 27,
#  'size': 28,
#  'tell': 29,
#  'them': 30,
#  'to': 31,
#  'wonder': 32,
#  'where': 33,
#  'the': 34,
#  'cold': 35,
#  'was': 36,
#  'coming': 37,
#  'from': 38,
#  'went': 39,
#  'till': 40,
#  'there': 41,
#  'were': 42,
#  'no': 43,
#  'cottages': 44,
#  'found': 45,
#  'this': 46,
#  'all': 47,
#  'olden': 48,
#  'jupiter': 49,
#  'several': 50,
#  'times': 51,
#  'over': 52,
#  'by': 53,
#  'marrying': 54,
#  'father': 55,
#  'when': 56,
#  'he': 57,
#  'made': 58,
#  'at': 59,
#  'tutelar': 60,
#  'shrine': 61,
#  'among': 62,
#  'unearthed': 63,
#  'potatoes': 64,
#  'standing': 65,
#  'still': 66,
#  'seraphic': 67,
#  'glancing': 68,
#  'thine': 69,
#  'eyes': 70,
#  'board': 71,
#  'we': 72,
#  'laid': 73,
#  'down': 74,
#  'walk': 75,
#  'dryshod': 76,
#  'on': 77,
#  'end': 78,
#  'not': 79,
#  'far': 80,
#  'going': 81,
#  'forth': 82,
#  'or': 83,
#  'been': 84,
#  'master': 85,
#  'grange': 86,
#  'what': 87,
#  'see': 88,
#  'its': 89,
#  'a': 90,
#  'little': 91,
#  'boy': 92,
#  'yankees': 93,
#  'are': 94,
#  'they': 95,
#  'always': 96,
#  'but': 97,
#  'you': 98,
#  'have': 99,
#  'said': 100,
#  'it': 101,
#  'off': 102,
#  'find': 103,
#  'nothing': 104,
#  'gold': 105,
#  'can': 106,
#  'stay': 107,
#  'hed': 108,
#  'like': 109,
#  'take': 110,
#  'me': 111,
#  'show': 112,
#  'truth': 113,
#  'virtue': 114,
#  'humanity': 115,
#  'call': 116,
#  'her': 117,
#  'nausicaa': 118,
#  'unafraid': 119,
#  'other': 120,
#  'listening': 121,
#  'things': 122,
#  'as': 123,
#  'leaves': 124,
#  'that': 125,
#  'crisped': 126,
#  'sere': 127,
#  'should': 128,
#  'say': 129,
#  'our': 130,
#  'stock': 131,
#  'petered': 132,
#  'out': 133,
#  'worlds': 134,
#  'shall': 135,
#  'be': 136,
#  'given': 137,
#  'pallor': 138,
#  'strangely': 139,
#  'mistrust': 140,
#  'fête': 141,
#  'today': 142,
#  'dew': 143,
#  'night': 144,
#  'time': 145,
#  'oer': 146,
#  'summer': 147,
#  'grass': 148,
#  'open': 149,
#  'temples': 150,
#  'graves': 151,
#  'settle': 152,
#  'hence': 153,
#  'blame': 154,
#  'his': 155,
#  'being': 156,
#  'brought': 157,
#  'up': 158,
#  'mother': 159,
#  'why': 160,
#  'two': 161,
#  'three': 162,
#  'shut': 163,
#  'ill': 164,
#  'do': 165,
#  'row': 166,
#  'who': 167,
#  'wouldst': 168,
#  'leave': 169,
#  'wandering': 170,
#  'however': 171,
#  'natural': 172,
#  'give': 173,
#  'your': 174,
#  'books': 175,
#  'cellar': 176,
#  'windows': 177,
#  'banked': 178,
#  'sawdust': 179,
#  'thy': 180,
#  'grace': 181,
#  'more': 182,
#  'than': 183,
#  'hers': 184,
#  'matter': 185,
#  'how': 186,
#  'many': 187,
#  'hes': 188,
#  'groping': 189,
#  'after': 190,
#  'jam': 191,
#  'whose': 192,
#  'heartstrings': 193,
#  'lute': 194,
#  'resurrection': 195,
#  'deepburied': 196,
#  'faith': 197,
#  'ruler': 198,
#  'realm': 199,
#  'seen': 200,
#  'hangs': 201,
#  'chains': 202,
#  'pearl': 203,
#  'hermon': 204,
#  'hill': 205,
#  'lying': 206,
#  'fell': 207,
#  'rejected': 208,
#  'sos': 209,
#  'everything': 210,
#  'builder': 211,
#  'building': 212,
#  'house': 213,
#  'realms': 214,
#  'boreal': 215,
#  'pole': 216,
#  'silver': 217,
#  'tinkling': 218,
#  'throats': 219,
#  'even': 220,
#  'thought': 221,
#  'coat': 222,
#  'good': 223,
#  'seated': 224,
#  'stone': 225,
#  'lead': 226,
#  'unprotected': 227,
#  'glass': 228,
#  'sat': 229,
#  'floor': 230,
#  'shouted': 231,
#  'toffile': 232,
#  'sweet': 233,
#  'day': 234,
#  'besides': 235,
#  'wear': 236,
#  'iron': 237,
#  'wagon': 238,
#  'wheels': 239,
#  'moving': 240,
#  'flock': 241,
#  'hens': 242,
#  'place': 243,
#  'love': 244,
#  'simple': 245,
#  'duty': 246,
#  'she': 247,
#  'revels': 248,
#  'region': 249,
#  'sighs': 250,
#  'upon': 251,
#  'way': 252,
#  'along': 253,
#  'wings': 254,
#  'until': 255,
#  'trailed': 256,
#  'dust': 257,
#  'save': 258,
#  'skies': 259,
#  'ashen': 260,
#  'sober': 261,
#  'here': 262,
#  'loveless': 263,
#  'birds': 264,
#  'now': 265,
#  'winter': 266,
#  'friends': 267,
#  'bout': 268,
#  'took': 269,
#  'long': 270,
#  'home': 271,
#  'bluebells': 272,
#  'gracing': 273,
#  'tunnel': 274,
#  'mouth': 275,
#  'alias': 276,
#  'john': 277,
#  'under': 278,
#  'spell': 279,
#  'so': 280,
#  'wrong': 281,
#  'ones': 282,
#  'cant': 283,
#  'italian': 284,
#  'tones': 285,
#  'only': 286,
#  'murmured': 287,
#  'oh': 288,
#  'hasten': 289,
#  'let': 290,
#  'us': 291,
#  'linger': 292,
#  'bird': 293,
#  'an': 294,
#  'angelic': 295,
#  'gift': 296,
#  'blotting': 297,
#  'utterly': 298,
#  'high': 299,
#  'heaven': 300,
#  'vast': 301,
#  'mean': 302,
#  'stark': 303,
#  'come': 304,
#  'despite': 305,
#  'lion': 306,
#  'lane': 307,
#  'yet': 308,
#  'might': 309,
#  'married': 310,
#  'about': 311,
#  'henry': 312,
#  'hudsons': 313,
#  'gone': 314,
#  'if': 315,
#  'must': 316,
#  'sunshine': 317,
#  'dont': 318,
#  'nature': 319,
#  'is': 320,
#  'hold': 321,
#  'those': 322,
#  'favor': 323,
#  'fire': 324,
#  'deal': 325,
#  'bad': 326,
#  'masonry': 327,
#  'because': 328,
#  'horse': 329,
#  'wont': 330,
#  'back': 331,
#  'worse': 332,
#  'son': 333,
#  'never': 334,
#  'could': 335,
#  'bones': 336,
#  'days': 337,
#  'heart': 338,
#  'volcanic': 339,
#  'whom': 340,
#  'absence': 341,
#  'arthur': 342,
#  'amy': 343,
#  'know': 344,
#  'idled': 345,
#  'lips': 346,
#  'melody': 347,
#  'broken': 348,
#  'drinking': 349,
#  'goblet': 350,
#  'grail': 351,
#  'softmurmured': 352,
#  'words': 353,
#  'light': 354,
#  'gnaws': 355,
#  'stable': 356,
#  'aint': 357,
#  'proof': 358,
#  'gets': 359,
#  'some': 360,
#  'sort': 361,
#  'bakeshop': 362,
#  'meals': 363,
#  'together': 364,
#  'eye': 365,
#  'man': 366,
#  'make': 367,
#  'free': 368,
#  'kick': 369,
#  'folks': 370,
#  'faces': 371,
#  'vision': 372,
#  'put': 373,
#  'same': 374,
#  'seize': 375,
#  'catscradle': 376,
#  'strings': 377,
#  'wake': 378,
#  'sigh': 379,
#  'blandishments': 380,
#  'would': 381,
#  'seem': 382,
#  'defied': 383,
#  'bring': 384,
#  'chalkpile': 385,
#  'hadnt': 386,
#  'gnaw': 387,
#  'posts': 388,
#  'lupine': 389,
#  'living': 390,
#  'sand': 391,
#  'drouth': 392,
#  'apple': 393,
#  'tree': 394,
#  'havent': 395,
#  'go': 396,
#  'farm': 397,
#  'frogs': 398,
#  'peeping': 399,
#  'thousand': 400,
#  'shrill': 401,
#  'bells': 402,
#  'though': 403,
#  'repeatedly': 404,
#  'strove': 405,
#  'just': 406,
#  'tent': 407,
#  'pegged': 408,
#  'fancied': 409,
#  'looked': 410,
#  'six': 411,
#  'oclock': 412,
#  'uncommonly': 413,
#  'deep': 414,
#  'snow': 415,
#  'has': 416,
#  'think': 417,
#  'horrible': 418,
#  'monody': 419,
#  'floats': 420,
#  'ask': 421,
#  'better': 422,
#  'oracle': 423,
#  'tending': 424,
#  'stardials': 425,
#  'hinted': 426,
#  'morn': 427,
#  'seems': 428,
#  'housework': 429,
#  'through': 430,
#  'presented': 431,
#  'land': 432,
#  'tide': 433,
#  'unfettered': 434,
#  'beats': 435,
#  'coupling': 436,
#  'fun': 437,
#  'bedeviled': 438,
#  'daylight': 439,
#  'birth': 440,
#  'supposed': 441,
#  'mad': 442,
#  'step': 443,
#  'trodden': 444,
#  'black': 445,
#  'joined': 446,
#  'excited': 447,
#  'myself': 448,
#  'neednt': 449,
#  'youre': 450,
#  'get': 451,
#  'away': 452,
#  'any': 453,
#  'mormon': 454,
#  'swimming': 455,
#  'senescent': 456,
#  'money': 457,
#  'suddenly': 458,
#  'into': 459,
#  'beyond': 460,
#  'shattered': 461,
#  'seedpod': 462,
#  'stood': 463,
#  'sing': 464,
#  'wildly': 465,
#  'well': 466,
#  'then': 467,
#  'granny': 468,
#  'speaking': 469,
#  'dunnow': 470,
#  'thinks': 471,
#  'wind': 472,
#  'makes': 473,
#  'tremulous': 474,
#  'which': 475,
#  'doth': 476,
#  'death': 477,
#  'looks': 478,
#  'gigantically': 479,
#  'sense': 480,
#  'having': 481,
#  'resurrected': 482,
#  'thered': 483,
#  'boston': 484,
#  'people': 485,
#  'poetesss': 486,
#  'state': 487,
#  'glory': 488,
#  'befitting': 489,
#  'burden': 490,
#  'body': 491,
#  'song': 492,
#  'tender': 493,
#  'verse': 494,
#  'escaped': 495,
#  'their': 496,
#  'outrage': 497,
#  'since': 498,
#  'flickers': 499,
#  'stopped': 500,
#  'sound': 501,
#  'feet': 502,
#  'viola': 503,
#  'follow': 504,
#  'situation': 505,
#  'road': 506,
#  'hole': 507,
#  'somewhere': 508,
#  'heel': 509,
#  'spirit': 510,
#  'dwell': 511,
#  'resignedly': 512,
#  'beneath': 513,
#  'sky': 514,
#  'sun': 515,
#  'did': 516,
#  'rivulets': 517,
#  'run': 518,
#  'will': 519,
#  'seek': 520,
#  'shelter': 521,
#  'happier': 522,
#  'star': 523,
#  'bet': 524,
#  'huse': 525,
#  'cribber': 526,
#  'gnawed': 527,
#  'sit': 528,
#  'fall': 529,
#  'keep': 530,
#  'abouncing': 531,
#  'forms': 532,
#  'move': 533,
#  'fantastically': 534,
#  'bear': 535,
#  'keeping': 536,
#  'youd': 537,
#  'baptismal': 538,
#  'font': 539,
#  'while': 540,
#  'listen': 541,
#  'red': 542,
#  'levin': 543,
#  'conquered': 544,
#  'scruples': 545,
#  'gloom': 546,
#  'nowhere': 547,
#  'drawn': 548,
#  'hearts': 549,
#  'passion': 550,
#  'tone': 551,
#  'perhaps': 552,
#  'claim': 553,
#  'round': 554,
#  'country': 555,
#  'village': 556,
#  'cultures': 557,
#  'faded': 558,
#  'runs': 559,
#  'unbridled': 560,
#  'course': 561,
#  'world': 562,
#  'sweets': 563,
#  'sours': 564,
#  'fulfilled': 565,
#  'yawning': 566,
#  'lenses': 567,
#  'glimpse': 568,
#  'curtain': 569,
#  'laces': 570,
#  'miraculous': 571,
#  'crescent': 572,
#  'grandsir': 573,
#  'distinctly': 574,
#  'years': 575,
#  'papered': 576,
#  'walls': 577,
#  'boys': 578,
#  'hunters': 579,
#  'known': 580,
#  'tis': 581,
#  'sell': 582,
#  'byroad': 583,
#  'something': 584,
#  'learned': 585,
#  'riding': 586,
#  'trains': 587,
#  'forward': 588,
#  'weakly': 589,
#  'handrail': 590,
#  'lie': 591,
#  'stones': 592,
#  'bushes': 593,
#  'unretrieved': 594,
#  'unless': 595,
#  'grave': 596,
#  'growing': 597,
#  'grown': 598,
#  'merrily': 599,
#  'live': 600,
#  'separate': 601,
#  'coops': 602,
#  'plumage': 603,
#  'done': 604,
#  'cried': 605,
#  'surely': 606,
#  'october': 607,
#  'truly': 608,
#  'men': 609,
#  'earth': 610,
#  'read': 611,
#  'another': 612,
#  'heat': 613,
#  'slowly': 614,
#  'hazes': 615,
#  'fullorbed': 616,
#  'moon': 617,
#  'own': 618,
#  'soul': 619,
#  'soaring': 620,
#  'greatness': 621,
#  'right': 622,
#  'stint': 623,
#  'used': 624,
#  'toteroad': 625,
#  'mounted': 626,
#  'ought': 627,
#  'thrown': 628,
#  'confusion': 629,
#  'near': 630,
#  'paradise': 631,
#  'pairing': 632,
#  'ends': 633,
#  'thrones': 634,
#  'longforgotten': 635,
#  'bowers': 636,
#  'want': 637,
#  'fountain': 638,
#  'path': 639,
#  'liquescent': 640,
#  'pendulous': 641,
#  'air': 642,
#  'beloved': 643,
#  'amid': 644,
#  'earnest': 645,
#  'woes': 646,
#  'mist': 647,
#  'bade': 648,
#  'pause': 649,
#  'before': 650,
#  'gardengate': 651,
#  'quickening': 652,
#  'pass': 653,
#  'attic': 654,
#  'sometimes': 655,
#  'tempted': 656,
#  'box': 657,
#  'fifty': 658,
#  'dollars': 659,
#  'langshang': 660,
#  'cock': 661,
#  'name': 662,
#  'waiting': 663,
#  'lest': 664,
#  'truant': 665,
#  'crystal': 666,
#  'palace': 667,
#  'london': 668,
#  'imported': 669,
#  'thing': 670,
#  'ours': 671,
#  'o': 672,
#  'may': 673,
#  'thrive': 674,
#  'against': 675,
#  'door': 676,
#  'nailed': 677,
#  'happy': 678,
#  'clime': 679,
#  'weight': 680,
#  'age': 681,
#  'snows': 682,
#  'started': 683,
#  'courting': 684,
#  'despairs': 685,
#  'unhallowed': 686,
#  'bed': 687,
#  'mistake': 688,
#  'piercing': 689,
#  'pull': 690,
#  'apart': 691,
#  'stifling': 692,
#  'hot': 693,
#  'odor': 694,
#  'sap': 695,
#  'nighttime': 696,
#  'brook': 697,
#  'wild': 698,
#  'descent': 699,
#  'greatly': 700,
#  'afraid': 701,
#  'estelles': 702,
#  'talk': 703,
#  'withering': 704,
#  'adding': 705,
#  'frost': 706,
#  'suppose': 707,
#  'deserves': 708,
#  'pity': 709,
#  'touch': 710,
#  'knows': 711,
#  'thats': 712,
#  'dear': 713,
#  'interest': 714,
#  'marked': 715,
#  'year': 716,
#  'shes': 717,
#  'worry': 718,
#  'strain': 719,
#  'forgot': 720,
#  'either': 721,
#  'cloud': 722,
#  'smoke': 723,
#  'advantage': 724,
#  'voices': 725,
#  'ago': 726,
#  'writer': 727,
#  'these': 728,
#  'lines': 729,
#  'unthoughtlike': 730,
#  'thoughts': 731,
#  'souls': 732,
#  'interfered': 733,
#  'business': 734,
#  'hail': 735,
#  'presence': 736,
#  'morning': 737,
#  'between': 738,
#  'nearest': 739,
#  'resembles': 740,
#  'worship': 741,
#  'remember': 742,
#  'serious': 743,
#  'aknown': 744,
#  'young': 745,
#  'helpless': 746,
#  'soon': 747,
#  'satisfied': 748,
#  'replied': 749,
#  'dreaming': 750,
#  'once': 751,
#  'journeyed': 752,
#  'scurf': 753,
#  'plants': 754,
#  'weary': 755,
#  'overheated': 756,
#  'sigmas': 757,
#  'taus': 758,
#  'neighbours': 759,
#  'turn': 760,
#  'doll': 761,
#  'pasture': 762,
#  'rig': 763,
#  'everyone': 764,
#  'miles': 765,
#  'charge': 766,
#  'upstart': 767,
#  'inexperience': 768,
#  'enough': 769,
#  'hate': 770,
#  'around': 771,
#  'text': 772,
#  'bidden': 773,
#  'thee': 774,
#  'rolls': 775,
#  'ether': 776,
#  'lavas': 777,
#  'restlessly': 778,
#  'roll': 779,
#  'comfort': 780,
#  'sew': 781,
#  'gives': 782,
#  'glimpses': 783,
#  'buy': 784,
#  'full': 785,
#  'lank': 786,
#  'shivery': 787,
#  'halfdrowned': 788,
#  'cows': 789,
#  'pigs': 790,
#  'break': 791,
#  'job': 792,
#  'israfel': 793,
#  'dimremembered': 794,
#  'story': 795,
#  'felt': 796,
#  'thrilling': 797,
#  'knew': 798,
#  'reason': 799,
#  'fingerbone': 800,
#  'wanted': 801,
#  'lost': 802,
#  'yourself': 803,
#  'fanes': 804,
#  'babylonlike': 805,
#  'hear': 806,
#  'word': 807,
#  'weather': 808,
#  'am': 809,
#  'guide': 810,
#  'feel': 811,
#  'easier': 812,
#  'threshold': 813,
#  'wideopen': 814,
#  'gate': 815,
#  'dreams': 816,
#  'second': 817,
#  'curving': 818,
#  'hillside': 819,
#  'much': 820,
#  'saw': 821,
#  'graveyard': 822,
#  'marble': 823,
#  'sculpture': 824,
#  'fervid': 825,
#  'flickering': 826,
#  'torch': 827,
#  'life': 828,
#  'lit': 829,
#  'invisible': 830,
#  'sink': 831,
#  'wife': 832,
#  'saved': 833,
#  'bright': 834,
#  'ready': 835,
#  'almost': 836,
#  'anything': 837,
#  'flowers': 838,
#  'merely': 839,
#  'further': 840,
#  'unearthly': 841,
#  'height': 842,
#  'therein': 843,
#  'ghoulhaunted': 844,
#  'woodland': 845,
#  'weir': 846,
#  'fervor': 847,
#  'power': 848,
#  'winged': 849,
#  'odour': 850,
#  'first': 851,
#  'look': 852,
#  'raspberry': 853,
#  'vines': 854,
#  'came': 855,
#  'coasting': 856,
#  'child': 857,
#  'captains': 858,
#  'dark': 859,
#  'fate': 860,
#  'window': 861,
#  'becoming': 862,
#  'reconciled': 863,
#  'gentle': 864,
#  'lot': 865,
#  'someone': 866,
#  'else': 867,
#  'lifes': 868,
#  'victories': 869,
#  'doubt': 870,
#  'motorcars': 871,
#  'asked': 872,
#  'sleeping': 873,
#  'warm': 874,
#  'fever': 875,
#  'minute': 876,
#  'lets': 877,
#  'rose': 878,
#  'pale': 879,
#  'perfumed': 880,
#  'gale': 881,
#  'bill': 882,
#  'showed': 883,
#  'signs': 884,
#  'fur': 885,
#  'trade': 886,
#  'dead': 887,
#  'crew': 888,
#  'failed': 889,
#  'wonderful': 890,
#  'plan': 891,
#  'without': 892,
#  'danger': 893,
#  'loss': 894,
#  'witch': 895,
#  'trembling': 896,
#  'wire': 897,
#  'cypress': 898,
#  'psyche': 899,
#  'headed': 900,
#  'for—': 901,
#  'blow': 902,
#  'selfclear': 903,
#  'dread': 904,
#  'wampum': 905,
#  'mind': 906,
#  'complain': 907,
#  'flashed': 908,
#  'licked': 909,
#  'upper': 910,
#  'teeth': 911,
#  'ah': 912,
#  'safely': 913,
#  'trust': 914,
#  'gleaming': 915,
#  'nonsense': 916,
#  'whats': 917,
#  'lofty': 918,
#  'original': 919,
#  'rage': 920,
#  'passed': 921,
#  'watchman': 922,
#  'beat': 923,
#  'lookoff': 924,
#  'faced': 925,
#  'often': 926,
#  'tail': 927,
#  'demon': 928,
#  'legs': 929,
#  'communing': 930,
#  'angels': 931,
#  'sought': 932,
#  'precipitate': 933,
#  'pathway': 934,
#  'alas': 935,
#  'cannot': 936,
#  'feeling': 937,
#  'richer': 938,
#  'wilder': 939,
#  'diviner': 940,
#  'visions': 941,
#  'adventure': 942,
#  'anyone': 943,
#  'idleness': 944,
#  'settlement': 945,
#  'wentworth': 946,
#  'alls': 947,
#  'breaking': 948,
#  'rode': 949,
#  'dangle': 950,
#  'fear': 951,
#  'treading': 952,
#  'forty': 953,
#  'plain': 954,
#  'statement': 955,
#  'relationship': 956,
#  'stumps': 957,
#  'bleeding': 958,
#  'jerk': 959,
#  'twitch': 960,
#  'last': 961,
#  'nights': 962,
#  'kiting': 963,
#  'purer': 964,
#  'except': 965,
#  'johnjoe': 966,
#  'leg': 967,
#  'crutch': 968,
#  'lipbegotten': 969,
#  'ye': 970,
#  'avengers': 971,
#  'libertys': 972,
#  'wrongs': 973,
#  'kept': 974,
#  'twas': 975,
#  'warmer': 976,
#  'dian': 977,
#  'goes': 978,
#  'fast': 979,
#  'earlier': 980,
#  'pay': 981,
#  'early': 982,
#  'leafs': 983,
#  'flower': 984,
#  'past': 985,
#  'both': 986,
#  'neither': 987,
#  'oho': 988,
#  'scenes': 989,
#  'departed': 990,
#  'bliss': 991,
#  'rain': 992,
#  'throw': 993,
#  'hoe': 994,
#  'recognize': 995,
#  'post': 996,
#  'yes': 997,
#  'ever': 998,
#  'bolder': 999,
#  ...}

# %%
def tokenize_and_convert(data, word_to_index):
    tokenized_data = []
    for line in data:
        words = line.split()
        tokenized_line = [word_to_index[word] if word in word_to_index else word_to_index["<UNK>"] for word in words]
        tokenized_data.append(tokenized_line)
    return tokenized_data


data_train_tokenized = tokenize_and_convert(train_text, word_to_index)
data_test_tokenized = tokenize_and_convert(test_text, word_to_index)

# %%
print(train_text[0])
print(data_train_tokenized[0])
# Out:
# with hope and in beauty tonight
# [1, 2, 3, 4, 5, 6]

# %%
def calculate_initial_state_distribution(word, distribution):
    count_word = distribution.get(word, 0)
    distribution[word] = count_word + 1
    
def get_initial_state_distribution(word, distribution, N, vocabulary_size):
    count_word = distribution.get(word, 0)
    return (count_word + 1) / (N + vocabulary_size)

# %%
# Define state transition matrix, calculate transition_counts, total_counts, vocab size and initial_state
# distribution and pi
def calculate_transitions_and_initial_distr(data, initial_state_distrib, transitions_counts_A, total_counts_A, vocab_size):
    for line in data:
        calculate_initial_state_distribution(line[0], initial_state_distrib)
        for i in range(len(line) - 1):
            total_counts_A[line[i]] =  total_counts_A.get(line[i], 0) + 1
            transitions_counts_A[(line[i], line[i+1])] = transitions_counts_A.get((line[i], line[i+1]), 0) + 1
            
transitions_counts_poe = {}
total_counts_poe = {}
vocab_size = len(word_to_index)
initial_state_distrib_poe = {}

data_train_tokenized_poe = [t for t, y in zip(data_train_tokenized, Ytrain) if y == 0]
calculate_transitions_and_initial_distr(data_train_tokenized_poe, initial_state_distrib_poe, transitions_counts_poe,
                                        total_counts_poe, vocab_size)

transitions_counts_frost = {}
total_counts_frost = {}
vocab_size = len(word_to_index)
initial_state_distrib_frost = {}

data_train_tokenized_frost = [t for t, y in zip(data_train_tokenized, Ytrain) if y == 1]
calculate_transitions_and_initial_distr([t for t, y in zip(data_train_tokenized, Ytrain) if y == 1], initial_state_distrib_frost, transitions_counts_frost,
                                        total_counts_frost, vocab_size)

# %%
print(transitions_counts_poe)
# Out:
# {(1, 2): 2, (2, 3): 2, (3, 4): 5, (4, 5): 6, (5, 6): 2, (46, 47): 1, (47, 46): 1, (46, 36): 1, (36, 4): 1, (4, 34): 31, (34, 48): 1, (56, 57): 1, (57, 58): 1, (58, 59): 1, (59, 34): 4, (34, 60): 1, (60, 61): 1, (34, 67): 2, (67, 68): 2, (68, 14): 2, (14, 69): 2, (69, 70): 5, (4, 113): 1, (113, 4): 1, (4, 114): 1, (114, 4): 1, (4, 115): 1, (3, 34): 10, (34, 120): 1, (120, 121): 1, (121, 122): 1, (123, 34): 14, (34, 124): 6, (124, 125): 3, (125, 42): 4, (42, 126): 3, (126, 3): 3, (3, 127): 9, (14, 87): 5, (87, 4): 2, (4, 120): 2, (120, 134): 2, (134, 135): 2, (135, 136): 3, (136, 3): 2, (3, 137): 2, (117, 138): 1, (138, 7): 1, (7, 139): 1, (139, 140): 1, (123, 143): 1, (143, 14): 1, (14, 34): 26, (34, 144): 8, (144, 145): 1, (145, 146): 1, (146, 34): 1, (34, 147): 2, (147, 148): 1, (41, 149): 1, (149, 150): 1, (150, 149): 1, (149, 151): 1, (74, 74): 1, (74, 125): 1, (125, 16): 2, (16, 135): 1, (135, 152): 1, (152, 153): 1, (167, 168): 1, (168, 79): 1, (79, 169): 1, (169, 20): 1, (20, 4): 1, (4, 155): 1, (155, 170): 1, (180, 181): 2, (181, 180): 1, (180, 182): 1, (182, 183): 1, (183, 5): 1, (192, 193): 1, (193, 94): 1, (94, 90): 1, (90, 194): 1, (26, 34): 2, (34, 195): 2, (195, 14): 2, (14, 196): 2, (196, 197): 2, (34, 198): 1, (198, 14): 1, (34, 199): 1, (199, 36): 1, (36, 200): 1, (125, 201): 2, (201, 109): 1, (109, 202): 1, (202, 14): 1, (14, 203): 1, (203, 77): 1, (77, 204): 1, (204, 205): 1, (34, 214): 2, (214, 14): 2, (34, 215): 2, (215, 216): 2, (38, 34): 5, (34, 217): 1, (217, 218): 1, (218, 219): 1, (4, 125): 2, (125, 233): 1, (233, 234): 1, (3, 244): 1, (244, 90): 1, (90, 245): 1, (245, 246): 1, (247, 248): 2, (248, 4): 2, (4, 90): 4, (90, 249): 2, (249, 14): 3, (14, 250): 4, (251, 34): 5, (34, 19): 1, (19, 3): 1, (3, 47): 4, (47, 34): 2, (34, 252): 1, (252, 253): 1, (254, 255): 2, (255, 95): 2, (95, 256): 4, (256, 4): 5, (34, 257): 5, (34, 259): 4, (259, 95): 2, (95, 42): 7, (42, 260): 2, (260, 3): 4, (3, 261): 6, (284, 285): 1, (285, 58): 1, (58, 286): 1, (286, 31): 1, (31, 136): 2, (136, 287): 1, (288, 289): 1, (289, 288): 1, (288, 290): 1, (290, 291): 7, (291, 79): 1, (79, 292): 1, (34, 297): 2, (297, 298): 2, (298, 38): 2, (38, 133): 4, (133, 299): 2, (299, 300): 2, (304, 158): 4, (158, 4): 3, (4, 305): 2, (305, 14): 2, (34, 306): 5, (41, 42): 1, (42, 337): 2, (337, 56): 2, (56, 27): 2, (27, 338): 5, (338, 36): 2, (36, 339): 2, (14, 47): 12, (47, 31): 1, (31, 340): 1, (340, 69): 1, (69, 341): 1, (341, 320): 1, (320, 34): 1, (94, 346): 1, (346, 3): 1, (47, 180): 2, (180, 347): 1, (59, 180): 2, (180, 352): 2, (352, 353): 3, (353, 290): 2, (290, 41): 2, (41, 136): 2, (136, 354): 2, (180, 338): 3, (338, 180): 1, (338, 7): 1, (7, 378): 1, (378, 3): 1, (3, 379): 1, (34, 402): 6, (402, 402): 4, (186, 418): 1, (418, 90): 1, (90, 419): 1, (419, 41): 1, (41, 420): 2, (34, 425): 2, (425, 426): 2, (426, 14): 2, (14, 427): 2, (186, 27): 1, (338, 435): 1, (435, 4): 1, (4, 436): 1, (436, 322): 1, (322, 161): 1, (161, 353): 1, (4, 439): 2, (439, 3): 2, (5, 38): 2, (38, 155): 2, (155, 440): 2, (3, 265): 2, (265, 123): 2, (144, 36): 2, (36, 456): 2, (101, 463): 1, (463, 41): 1, (57, 309): 1, (309, 79): 1, (79, 464): 1, (464, 280): 1, (280, 465): 1, (465, 466): 1, (291, 77): 2, (77, 53): 2, (53, 46): 2, (46, 474): 2, (474, 354): 2, (14, 475): 3, (475, 101): 1, (101, 476): 1, (476, 265): 1, (265, 344): 1, (477, 478): 1, (478, 479): 1, (479, 74): 1, (4, 487): 1, (487, 155): 1, (155, 488): 1, (488, 466): 1, (466, 489): 1, (498, 101): 1, (101, 499): 2, (499, 158): 2, (158, 31): 1, (31, 300): 1, (300, 430): 1, (430, 34): 6, (4, 300): 3, (300, 90): 1, (90, 510): 1, (510, 476): 1, (476, 511): 1, (512, 513): 1, (513, 34): 2, (34, 514): 4, (125, 4): 1, (34, 515): 5, (515, 516): 1, (516, 517): 1, (517, 518): 1, (31, 520): 2, (520, 90): 1, (90, 521): 1, (521, 4): 1, (4, 360): 2, (360, 522): 1, (522, 523): 1, (301, 532): 1, (532, 125): 1, (125, 533): 1, (533, 534): 1, (540, 31): 1, (31, 541): 1, (541, 34): 1, (34, 542): 1, (542, 543): 1, (3, 544 ...

# %%
import numpy as np

# Adjusted normalization to directly create numpy arrays/matrices
def create_normalized_matrices(transition_counts, total_counts, initial_state_distrib, N, V):
    # Initialize with add-one smoothing
    A = np.ones((V, V))
    pi = np.ones(V)
    
    # Apply counts (add-one is already in initial values)
    for (prev_word, next_word), count in transition_counts.items():
        A[prev_word, next_word] += count  # Already 1, so just add count
    for word, count in initial_state_distrib.items():
        pi[word] += count
    
    # Normalize
    A /= A.sum(axis=1, keepdims=True)
    pi /= pi.sum()
    
    # Convert to log space
    logA = np.log(A)
    logpi = np.log(pi)
    
    return logA, logpi

N_poe = len(data_train_tokenized_poe)
N_frost = len(data_train_tokenized_frost)
logA_poe, logpi_poe = create_normalized_matrices(transitions_counts_poe, total_counts_poe, initial_state_distrib_poe, N_poe, vocab_size)
logA_frost, logpi_frost = create_normalized_matrices(transitions_counts_frost, total_counts_frost, initial_state_distrib_frost, N_frost, vocab_size)

# %%
lenPoe = len(labels_poe)
lenFrost = len(labels_frost)

total = lenPoe + lenFrost
p0 = lenPoe / total
p1 = lenFrost / total
logp0 = np.log(p0)
logp1 = np.log(p1)
p0, p1
# Out:
# (0.3333333333333333, 0.6666666666666666)

# %%
def calculate_log_sequence_probability(test_line, logA, logpi):
    if not test_line:
        return float('-inf')  # log probability of an empty sequence is negative infinity
    
    # Assuming test_line is a sequence of indices
    log_prob = logpi[test_line[0]]  # Start with log probability of the initial state
    for i in range(1, len(test_line)):
        log_prob += logA[test_line[i-1], test_line[i]]  # Add log transition probabilities
    
    return log_prob

# %%
import random

indices_with_1 = np.where(np.array(Ytest) == 1)[0]

random_index = random.choice(indices_with_1)

test_data_ex = data_test_tokenized[random_index]

prob_poe = calculate_log_sequence_probability(test_data_ex, logA_poe, logpi_poe)
prob_frost = calculate_log_sequence_probability(test_data_ex, logA_frost, logpi_frost)

print(prob_poe)
print(prob_frost)
# Out:
# -60.32816776411826
# -57.81091699488259

# %%
# Compute argmax of log of probabilities for each class
import math

def predict_author(test_line, logA_poe, logpi_poe, logp_poe, logA_frost, logpi_frost, logp_frost):
    # Calculate the total log likelihood + log prior for each class
    log_likelihood_poe = calculate_log_sequence_probability(test_line, logA_poe, logpi_poe) + logp_poe
    log_likelihood_frost = calculate_log_sequence_probability(test_line, logA_frost, logpi_frost) + logp_frost
    
    # Compare and predict
    if log_likelihood_poe > log_likelihood_frost:
        return 'Edgar Allan Poe', 0  # Returning label and class index
    else:
        return 'Robert Frost', 1

author, _ = predict_author(test_data_ex, logA_poe, logpi_poe, logp0, logA_frost, logpi_frost, logp1)
print(f"The class with the maximum log probability is: {author}")
# Out:
# The class with the maximum log probability is: Robert Frost

# %%
def calculate_accuracy(data_tokenized, true_labels):
    correct_predictions = 0
    for i, line in enumerate(data_tokenized):
        _, predicted_label = predict_author(line, logA_poe, logpi_poe, logp0, logA_frost, logpi_frost, logp1)
        if predicted_label == true_labels[i]:
            correct_predictions += 1
    accuracy = correct_predictions / len(data_tokenized)
    return accuracy

# Calculate and print accuracies
accuracy_train = calculate_accuracy(data_train_tokenized, Ytrain)
accuracy_test = calculate_accuracy(data_test_tokenized, Ytest)

print(f"Train accuracy: {accuracy_train}")
print(f"Test accuracy: {accuracy_test}")
# Out:
# Train accuracy: 0.9950464396284829
# Test accuracy: 0.8126159554730983
